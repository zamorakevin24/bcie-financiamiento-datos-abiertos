# %%
import pandas as pd

# %%
df_aprobaciones = pd.read_csv('aprobaciones-prestamos.csv')
df_desembolsos = pd.read_csv('desembolsos-prestamos.csv')

# %%
df_aprobaciones.head()
# Out:
#          PAIS  ANIO_APROBACION SECTOR_INSTITUCIONAL  MONTO_BRUTO_USD  \
# 0  Costa Rica             2012       Sector Privado        3000000.0
# 1   Argentina             2022       Sector Público      115000000.0
# 2   Argentina             2015       Sector Público       50000000.0
# 3   Argentina             2017       Sector Público       30000000.0
# 4  Costa Rica             2003       Sector Privado       54336000.0
#
#    CANTIDAD_APROBACIONES
# 0                      1
# 1                      4
# 2                      1
# 3                      1
# 4                     12

# %%
df_desembolsos.head()
# Out:
#           PAIS  ANIO_DESEMBOLSO SECTOR_INSTITUCIONAL  MONTO_BRUTO_USD
# 0   Costa Rica             1965       Sector Público       1994591.79
# 1  El Salvador             1967       Sector Público       4695698.73
# 2     Honduras             1964       Sector Público       1262295.16
# 3    Guatemala             1964       Sector Público       2250000.00
# 4         Cuba             2024       Sector Público      28794236.23

# %%
df_aprobaciones.shape
# Out:
# (609, 5)

# %%
df_desembolsos.shape
# Out:
# (410, 4)

# %%
df_aprobaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 609 entries, 0 to 608
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PAIS                   609 non-null    object
#  1   ANIO_APROBACION        609 non-null    int64
#  2   SECTOR_INSTITUCIONAL   609 non-null    object
#  3   MONTO_BRUTO_USD        609 non-null    float64
#  4   CANTIDAD_APROBACIONES  609 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 23.9+ KB

# %%
df_aprobaciones.columns
# Out:
# Index(['PAIS', 'ANIO_APROBACION', 'SECTOR_INSTITUCIONAL', 'MONTO_BRUTO_USD',
#        'CANTIDAD_APROBACIONES'],
#       dtype='object')

# %%
df_aprobaciones.isnull().sum()
# Out:
# PAIS                     0
# ANIO_APROBACION          0
# SECTOR_INSTITUCIONAL     0
# MONTO_BRUTO_USD          0
# CANTIDAD_APROBACIONES    0
# dtype: int64

# %%
sorted(df_aprobaciones['ANIO_APROBACION'].unique())
# Out:
# [1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023,
#  2024,
#  2025]

# %%
df_desembolsos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410 entries, 0 to 409
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PAIS                  410 non-null    object
#  1   ANIO_DESEMBOLSO       410 non-null    int64
#  2   SECTOR_INSTITUCIONAL  410 non-null    object
#  3   MONTO_BRUTO_USD       410 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 12.9+ KB

# %%
df_desembolsos.columns
# Out:
# Index(['PAIS', 'ANIO_DESEMBOLSO', 'SECTOR_INSTITUCIONAL', 'MONTO_BRUTO_USD'], dtype='object')

# %%
df_desembolsos.isnull().sum()
# Out:
# PAIS                    0
# ANIO_DESEMBOLSO         0
# SECTOR_INSTITUCIONAL    0
# MONTO_BRUTO_USD         0
# dtype: int64

# %%
sorted(df_desembolsos['ANIO_DESEMBOLSO'].unique())
# Out:
# [1964,
#  1965,
#  1966,
#  1967,
#  1969,
#  1970,
#  1974,
#  1975,
#  1976,
#  1978,
#  1980,
#  1981,
#  1982,
#  1983,
#  1986,
#  1987,
#  1988,
#  1989,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023,
#  2024,
#  2025]

# %%
df_aprobaciones['DECADA'] = (df_aprobaciones['ANIO_APROBACION'] // 10) * 10

# %%
df_aprobaciones.head(10)
# Out:
#          PAIS  ANIO_APROBACION SECTOR_INSTITUCIONAL  MONTO_BRUTO_USD  \
# 0  Costa Rica             2012       Sector Privado        3000000.0
# 1   Argentina             2022       Sector Público      115000000.0
# 2   Argentina             2015       Sector Público       50000000.0
# 3   Argentina             2017       Sector Público       30000000.0
# 4  Costa Rica             2003       Sector Privado       54336000.0
# 5      Belice             2014       Sector Público       30000000.0
# 6      Belice             2009       Sector Público        1905800.0
# 7    Colombia             2008       Sector Privado        5000000.0
# 8  Costa Rica             1965       Sector Privado        1284100.0
# 9  Costa Rica             1981       Sector Privado        2771000.0
#
#    CANTIDAD_APROBACIONES  DECADA
# 0                      1    2010
# 1                      4    2020
# 2                      1    2010
# 3                      1    2010
# 4                     12    2000
# ...

# %%
sorted(df_aprobaciones['DECADA'].unique())
# Out:
# [1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
df_desembolsos['DECADA'] = (df_desembolsos['ANIO_DESEMBOLSO'] // 10) * 10
df_desembolsos.head(10)
# Out:
#                    PAIS  ANIO_DESEMBOLSO SECTOR_INSTITUCIONAL  \
# 0            Costa Rica             1965       Sector Público
# 1           El Salvador             1967       Sector Público
# 2              Honduras             1964       Sector Público
# 3             Guatemala             1964       Sector Público
# 4                  Cuba             2024       Sector Público
# 5              Colombia             2016       Sector Público
# 6             Argentina             2017       Sector Público
# 7  República Dominicana             2009       Sector Público
# 8                México             2017       Sector Público
# 9                Belice             2010       Sector Público
#
#    MONTO_BRUTO_USD  DECADA
# 0     1.994592e+06    1960
# 1     4.695699e+06    1960
# 2     1.262295e+06    1960
# 3     2.250000e+06    1960
# 4     2.879424e+07    2020
# 5     1.860000e+08    2010
# 6     2.625000e+06    2010
# 7     4.629531e+07    2000
# 8     1.425000e+08    2010
# ...

# %%
sorted(df_desembolsos['DECADA'].unique())
# Out:
# [1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
(df_aprobaciones['PAIS'].unique())
# Out:
# array(['Costa Rica', 'Argentina', 'Belice', 'Colombia', 'El Salvador',
#        'Guatemala', 'Honduras', 'Nicaragua', 'Cuba', 'Panamá',
#        'República Dominicana', 'México', 'Regional'], dtype=object)

# %%
sorted(df_aprobaciones['SECTOR_INSTITUCIONAL'].unique())
# Out:
# ['Sector Privado', 'Sector Público']

# %%
(df_desembolsos['PAIS'].unique())
# Out:
# array(['Costa Rica', 'El Salvador', 'Honduras', 'Guatemala', 'Cuba',
#        'Colombia', 'Argentina', 'República Dominicana', 'México',
#        'Belice', 'Panamá', 'Nicaragua'], dtype=object)

# %%
sorted(df_desembolsos['SECTOR_INSTITUCIONAL'].unique())
# Out:
# ['Sector Privado', 'Sector Público']

# %%
df_aprobaciones['TIPO'] = 'Aprobacion'

# %%
df_desembolsos['TIPO'] = 'Desembolso'

# %%
df_aprobaciones.head()
# Out:
#          PAIS  ANIO_APROBACION SECTOR_INSTITUCIONAL  MONTO_BRUTO_USD  \
# 0  Costa Rica             2012       Sector Privado        3000000.0
# 1   Argentina             2022       Sector Público      115000000.0
# 2   Argentina             2015       Sector Público       50000000.0
# 3   Argentina             2017       Sector Público       30000000.0
# 4  Costa Rica             2003       Sector Privado       54336000.0
#
#    CANTIDAD_APROBACIONES  DECADA        TIPO
# 0                      1    2010  Aprobacion
# 1                      4    2020  Aprobacion
# 2                      1    2010  Aprobacion
# 3                      1    2010  Aprobacion
# 4                     12    2000  Aprobacion

# %%
df_desembolsos.head()
# Out:
#           PAIS  ANIO_DESEMBOLSO SECTOR_INSTITUCIONAL  MONTO_BRUTO_USD  DECADA  \
# 0   Costa Rica             1965       Sector Público       1994591.79    1960
# 1  El Salvador             1967       Sector Público       4695698.73    1960
# 2     Honduras             1964       Sector Público       1262295.16    1960
# 3    Guatemala             1964       Sector Público       2250000.00    1960
# 4         Cuba             2024       Sector Público      28794236.23    2020
#
#          TIPO
# 0  Desembolso
# 1  Desembolso
# 2  Desembolso
# 3  Desembolso
# 4  Desembolso

# %%
df_aprobaciones['MONTO_BRUTO_USD'].sum()
# Out:
# 57166029524.079994

# %%
max_aprob = pd.DataFrame(df_aprobaciones.groupby('ANIO_APROBACION')['MONTO_BRUTO_USD'].sum())
max_aprob.head()
# Out:
#                  MONTO_BRUTO_USD
# ANIO_APROBACION
# 1961                   275000.00
# 1962                  3238200.00
# 1963                 11104848.57
# 1964                 17096093.00
# 1965                 20638447.00

# %%
id_max=max_aprob.idxmax()
monto_max = max_aprob['MONTO_BRUTO_USD'].max()
print(id_max,monto_max)
# Out:
# MONTO_BRUTO_USD    2022
# dtype: int64 4290000000.0

# %%
df_aprobaciones.head()
# Out:
#          PAIS  ANIO_APROBACION SECTOR_INSTITUCIONAL  MONTO_BRUTO_USD  \
# 0  Costa Rica             2012       Sector Privado        3000000.0
# 1   Argentina             2022       Sector Público      115000000.0
# 2   Argentina             2015       Sector Público       50000000.0
# 3   Argentina             2017       Sector Público       30000000.0
# 4  Costa Rica             2003       Sector Privado       54336000.0
#
#    CANTIDAD_APROBACIONES  DECADA        TIPO
# 0                      1    2010  Aprobacion
# 1                      4    2020  Aprobacion
# 2                      1    2010  Aprobacion
# 3                      1    2010  Aprobacion
# 4                     12    2000  Aprobacion

# %%
df_aprobaciones['CANTIDAD_APROBACIONES'].sum()
# Out:
# 3135

# %%
df_desembolsos['MONTO_BRUTO_USD'].sum()
# Out:
# 43181979791.15

# %%
df_desembolsos.head()
# Out:
#           PAIS  ANIO_DESEMBOLSO SECTOR_INSTITUCIONAL  MONTO_BRUTO_USD  DECADA  \
# 0   Costa Rica             1965       Sector Público       1994591.79    1960
# 1  El Salvador             1967       Sector Público       4695698.73    1960
# 2     Honduras             1964       Sector Público       1262295.16    1960
# 3    Guatemala             1964       Sector Público       2250000.00    1960
# 4         Cuba             2024       Sector Público      28794236.23    2020
#
#          TIPO
# 0  Desembolso
# 1  Desembolso
# 2  Desembolso
# 3  Desembolso
# 4  Desembolso

# %%
df_desembolsos.groupby('ANIO_DESEMBOLSO')['MONTO_BRUTO_USD'].sum().to_dict()
# Out:
# {1964: 3512295.16,
#  1965: 1994591.79,
#  1966: 8913863.09,
#  1967: 4695698.73,
#  1969: 1933.57,
#  1970: 64870.77,
#  1974: 6140000.0,
#  1975: 2832769.52,
#  1976: 28975921.490000002,
#  1978: 200000.0,
#  1980: 148750.0,
#  1981: 30908267.91,
#  1982: 3989674.82,
#  1983: 4838148.38,
#  1986: 2365397.85,
#  1987: 1611007.24,
#  1988: 46075095.379999995,
#  1989: 49335114.26,
#  1991: 24936535.7,
#  1992: 41310263.03,
#  1993: 22834266.93,
#  1994: 60726664.24,
#  1995: 49923394.86,
#  1996: 862451610.3299999,
#  1997: 917684410.3299999,
#  1998: 620522073.49,
#  1999: 521271409.21,
#  2000: 457498700.19,
#  2001: 632091264.6,
#  2002: 1119498932.64,
#  2003: 1152426695.13,
#  2004: 1105526121.8,
#  2005: 1306292691.6599998,
#  2006: 1648145420.06,
#  2007: 1475013199.53,
#  2008: 1666463740.4299998,
#  2009: 1204873448.65,
#  2010: 1156160794.1499999,
#  2011: 1371889122.18,
#  2012: 1432572662.88,
#  2013: 1444497626.97,
#  2014: 1564238243.75,
#  2015: 1503422198.6,
# ...

# %%
desembolso = pd.DataFrame(df_desembolsos.groupby('ANIO_DESEMBOLSO')['MONTO_BRUTO_USD'].sum())

# %%
id_max=desembolso.idxmax()
monto_max = desembolso['MONTO_BRUTO_USD'].max()
print(id_max,monto_max)
# Out:
# MONTO_BRUTO_USD    2023
# dtype: int64 2702691801.92

# %%
id_min=desembolso.idxmin()
monto_min = desembolso['MONTO_BRUTO_USD'].min()
print(id_min,monto_min)
# Out:
# MONTO_BRUTO_USD    1969
# dtype: int64 1933.57

# %%
(df_aprobaciones['ANIO_APROBACION'].nunique())
# Out:
# 65

# %%
df_desembolsos.count()
# Out:
# PAIS                    410
# ANIO_DESEMBOLSO         410
# SECTOR_INSTITUCIONAL    410
# MONTO_BRUTO_USD         410
# DECADA                  410
# TIPO                    410
# dtype: int64

# %%
aprobaciones_anio = pd.DataFrame(df_aprobaciones.groupby('ANIO_APROBACION')['MONTO_BRUTO_USD'].sum())

# %%
aprobaciones_anio.head()
# Out:
#                  MONTO_BRUTO_USD
# ANIO_APROBACION
# 1961                   275000.00
# 1962                  3238200.00
# 1963                 11104848.57
# 1964                 17096093.00
# 1965                 20638447.00

# %%
desembolsos_anio = pd.DataFrame(df_desembolsos.groupby('ANIO_DESEMBOLSO')['MONTO_BRUTO_USD'].sum())

# %%
desembolsos_anio.head()
# Out:
#                  MONTO_BRUTO_USD
# ANIO_DESEMBOLSO
# 1964                  3512295.16
# 1965                  1994591.79
# 1966                  8913863.09
# 1967                  4695698.73
# 1969                     1933.57

# %%
aprobaciones_decada = pd.DataFrame(df_aprobaciones.groupby('DECADA')['MONTO_BRUTO_USD'].sum())

# %%
aprobaciones_decada
# Out:
#         MONTO_BRUTO_USD
# DECADA
# 1960       2.148119e+08
# 1970       1.142055e+09
# 1980       9.578069e+08
# 1990       4.423478e+09
# 2000       1.217663e+10
# 2010       1.866732e+10
# 2020       1.958393e+10

# %%
desembolsos_decada = pd.DataFrame(df_desembolsos.groupby('DECADA')['MONTO_BRUTO_USD'].sum())

# %%
desembolsos_decada
# Out:
#         MONTO_BRUTO_USD
# DECADA
# 1960       1.911838e+07
# 1970       3.821356e+07
# 1980       1.392715e+08
# 1990       3.121661e+09
# 2000       1.176783e+10
# 2010       1.524915e+10
# 2020       1.284673e+10

# %%
(df_desembolsos.groupby('ANIO_DESEMBOLSO')['MONTO_BRUTO_USD'].count())
# Out:
# ANIO_DESEMBOLSO
# 1964     2
# 1965     1
# 1966     2
# 1967     1
# 1969     1
# 1970     1
# 1974     2
# 1975     1
# 1976     3
# 1978     1
# 1980     1
# 1981     3
# 1982     1
# 1983     1
# 1986     1
# 1987     1
# 1988     3
# 1989     5
# 1991     5
# 1992     6
# 1993     6
# 1994     7
# 1995     6
# 1996     9
# 1997    10
# 1998    10
# 1999     9
# 2000     9
# 2001     9
# 2002     9
# 2003     9
# 2004    10
# 2005    10
# 2006     9
# 2007    10
# 2008    10
# 2009    12
# 2010    13
# 2011    12
# 2012    12
# 2013    13
# 2014    12
# 2015    12
# 2016    12
# 2017    15
# 2018    15
# 2019    14
# 2020    13
# 2021    13
# 2022    13
# 2023    16
# 2024    16
# 2025    13
# Name: MONTO_BRUTO_USD, dtype: int64

# %%
(df_aprobaciones.groupby('DECADA')['MONTO_BRUTO_USD'].count())
# Out:
# DECADA
# 1960     73
# 1970     99
# 1980     60
# 1990     86
# 2000    107
# 2010    120
# 2020     64
# Name: MONTO_BRUTO_USD, dtype: int64

# %%
(df_aprobaciones.groupby('ANIO_APROBACION')['MONTO_BRUTO_USD'].count().to_dict())
# Out:
# {1961: 1,
#  1962: 5,
#  1963: 8,
#  1964: 10,
#  1965: 10,
#  1966: 10,
#  1967: 9,
#  1968: 10,
#  1969: 10,
#  1970: 10,
#  1971: 10,
#  1972: 10,
#  1973: 10,
#  1974: 10,
#  1975: 10,
#  1976: 10,
#  1977: 9,
#  1978: 10,
#  1979: 10,
#  1980: 9,
#  1981: 10,
#  1982: 9,
#  1983: 5,
#  1984: 4,
#  1985: 4,
#  1986: 4,
#  1987: 6,
#  1988: 3,
#  1989: 6,
#  1990: 6,
#  1991: 7,
#  1992: 9,
#  1993: 10,
#  1994: 10,
#  1995: 10,
#  1996: 9,
#  1997: 9,
#  1998: 9,
#  1999: 7,
#  2000: 9,
#  2001: 9,
#  2002: 10,
#  2003: 10,
#  2004: 10,
#  2005: 12,
#  2006: 9,
#  2007: 14,
#  2008: 12,
#  2009: 12,
#  2010: 14,
#  2011: 11,
#  2012: 9,
#  2013: 10,
#  2014: 12,
#  2015: 14,
#  2016: 13,
#  2017: 15,
#  2018: 10,
#  2019: 12,
#  2020: 10,
#  2021: 11,
#  2022: 15,
#  2023: 8,
#  2024: 8,
#  2025: 12}

# %%
df_aprobaciones.columns
# Out:
# Index(['PAIS', 'ANIO_APROBACION', 'SECTOR_INSTITUCIONAL', 'MONTO_BRUTO_USD',
#        'CANTIDAD_APROBACIONES', 'DECADA', 'TIPO'],
#       dtype='object')

# %%
aprobaciones_pais = pd.DataFrame(df_aprobaciones.groupby('PAIS')['MONTO_BRUTO_USD'].sum())

# %%
aprobaciones_pais.sort_values(by="MONTO_BRUTO_USD", ascending=False).head(5)
# Out:
#              MONTO_BRUTO_USD
# PAIS
# Costa Rica      1.384132e+10
# El Salvador     1.010890e+10
# Honduras        9.237314e+09
# Nicaragua       7.744200e+09
# Guatemala       7.331794e+09

# %%
desembolsos_pais = pd.DataFrame(df_desembolsos.groupby('PAIS')['MONTO_BRUTO_USD'].sum())

# %%
desembolsos_pais.sort_values(by="MONTO_BRUTO_USD", ascending=False).head(5)
# Out:
#              MONTO_BRUTO_USD
# PAIS
# Costa Rica      1.010291e+10
# El Salvador     9.413078e+09
# Guatemala       6.009661e+09
# Honduras        5.995158e+09
# Nicaragua       5.982712e+09

# %%
df_aprobaciones.groupby('SECTOR_INSTITUCIONAL')['MONTO_BRUTO_USD'].sum()
# Out:
# SECTOR_INSTITUCIONAL
# Sector Privado    9.384119e+09
# Sector Público    4.778191e+10
# Name: MONTO_BRUTO_USD, dtype: float64

# %%
df_desembolsos.groupby('SECTOR_INSTITUCIONAL')['MONTO_BRUTO_USD'].sum()
# Out:
# SECTOR_INSTITUCIONAL
# Sector Privado    1.407492e+10
# Sector Público    2.910706e+10
# Name: MONTO_BRUTO_USD, dtype: float64

# %%
df_aprobaciones.to_csv('aprobaciones_limpias.csv', index=False)
df_desembolsos.to_csv('desembolsos_limpios.csv', index=False)
